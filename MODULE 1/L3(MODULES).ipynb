# %% [markdown]
# MODULES AND IMPORT STATEMENTS :
#
# MODULE:
# It is  a script file of Python functions , variables , or classes .
#
#
# import [module_name].[class_name]

# %%
import datetime
today = datetime.date.today() 
timenow = datetime.datetime.now().time()

print("Todays date:" , today)
print()

print("Time:" ,timenow)
print()

d = datetime.date(2024 , 1 ,31 )
d.replace(month = 12)
print(d)

#as syntax 

import datetime as dt 

start_time=dt.datetime.now()
# Out:
# Todays date: 2026-04-04
#
# Time: 23:36:55.520676
#
# 2024-01-31

# %%
import time 

seconds=time.time()
print("Time after epoxy :" , seconds)  #prints time elapsed from  January 1970
# Out:
# Time after epoxy : 1775326120.800835

# %%
import time

unix_timestamp = time.time()
local_time = time.localtime(unix_timestamp)

print()

#print(time.strftime(%D - %M - %Y: "H":"M":"S"))
# Out:
#   Cell In[21], line 8
#     print(time.strftime(%D - %M - %Y: "H":"M":"S"))
#                         ^
# SyntaxError: invalid syntax
